# %%
import pandas as pd

# %%
intent_df=pd.read_csv("./data/synthetic_sessions.csv")
intent_df.head()
# Out:
#    session_length                                           features  \
# 0               3  product_view random item general category_view...
# 1               5  search best arabica coffee search coffee near ...
# 2               5  signup_complete google category_view new user ...
# 3               5  category_view summer dresses add_to_cart linen...
# 4               2  search summer fashion trends product_view air ...
#
#               label
# 0   coffee_interest
# 1   coffee_interest
# 2     signup_intent
# 3  fashion_interest
# 4  fashion_interest
